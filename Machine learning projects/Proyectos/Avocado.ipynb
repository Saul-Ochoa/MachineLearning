# %% [markdown]
# <a href="https://colab.research.google.com/github/Saul-Ochoa/Python-MachineLearning/blob/main/Machine%20learning%20projects/Avocado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Avocado**

# %% [markdown]
# * Date - The date of the observation
# * AveragePrice - the average price of a single avocado
# * type - conventional or organic
# * year - the year
# * Region - the city or region of the observation
# * Total Volume - Total number of avocados sold
# * 4046 - Total number of avocados with PLU 4046 sold
# * 4225 - Total number of avocados with PLU 4225 sold
# * 4770 - Total number of avocados with PLU 4770 sold

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import time
import warnings
warnings.filterwarnings('ignore')

# %%
url='https://raw.githubusercontent.com/Saul-Ochoa/Python-MachineLearning/main/Machine%20learning%20projects/Data/avocado.csv'
df=pd.read_csv(url)
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.drop('Unnamed: 0',inplace=True,axis=1)
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df['Date']=pd.to_datetime(df['Date'],format='%Y/%m/%d')
df['year']=pd.to_datetime(df['year'],format='%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  datetime64[ns]
#  12  region        18249 non-null  object
# dtypes: datetime64[ns](2), float64(9), object(2)
# memory usage: 1.8+ MB

# %%
cat=df.select_dtypes(include='object').columns
df_cat=df[cat]
df_cat.head()
# Out:
#            type  region
# 0  conventional  Albany
# 1  conventional  Albany
# 2  conventional  Albany
# 3  conventional  Albany
# 4  conventional  Albany

# %%
sns.histplot(data=df,x='AveragePrice',hue='type')
plt.title('Promedio de Avocado por Tipo',fontsize=10,weight='bold')
plt.show()

# %%
for i in cat:
  print(f'Tipo de columnas Categoricas {i}')
  print('----------------------------------------')
  print(df_cat[i].value_counts())
# Out:
# Tipo de columnas Categoricas type
# ----------------------------------------
# conventional    9126
# organic         9123
# Name: type, dtype: int64
# Tipo de columnas Categoricas region
# ----------------------------------------
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# ...

# %%
for i in cat:
  plt.figure(figsize=(12,10))
  sns.countplot(x=df_cat[i])
  plt.xticks(rotation='vertical')
  plt.title(i)
  plt.show()

# %%
num=df.select_dtypes(include='number').columns
num
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags'],
#       dtype='object')

# %%
df_num=df[num]
df_num.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags
# 0     8603.62       93.25          0.0
# 1     9408.07       97.49          0.0
# 2     8042.21      103.14          0.0
# 3     5677.40      133.76          0.0
# 4     5986.26      197.69          0.0

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_num.corr(),annot=True)
plt.title('Mapa de Calor',fontsize=10,weight='bold')
plt.show()

# %%
for i in num:
  sns.histplot(df_num[i])
  plt.title(i,fontsize=10,weight='bold')
  plt.show()

# %%
sns.lineplot(data=df,x='Date',y='AveragePrice',hue='type')
plt.title('AveragePrice by Type',fontsize=10,weight='bold')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.lineplot(data=df,x='Date',y='4046',hue='type')
plt.title('Total number of avocados with PLU 4046 sold',fontsize=10,weight='bold')
plt.xticks(rotation='vertical')
plt.ylabel('PLU 4046 sold')
plt.show()

# %%
sns.lineplot(data=df,x='Date',y='4225',hue='type')
plt.title('Total number of avocados with PLU 4046 sold',fontsize=10,weight='bold')
plt.xticks(rotation='vertical')
plt.ylabel('PLU 4225 sold')
plt.show()

# %%
sns.lineplot(data=df,x='Date',y='4770',hue='type')
plt.title('Total number of avocados with PLU 4770 sold',fontsize=10,weight='bold')
plt.xticks(rotation='vertical')
plt.ylabel('PLU 4770 sold')
plt.show()

# %%
for i in num:
  sns.lineplot(data=df,x='Date',y=i)
  plt.title(i)
  plt.xticks(rotation='vertical')
  plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['type']=le.fit_transform(df['type'])
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type       year  region
# 0     8696.87     8603.62       93.25          0.0     0 2015-01-01  Albany
# 1     9505.56     9408.07       97.49          0.0     0 2015-01-01  Albany
# 2     8145.35     8042.21      103.14          0.0     0 2015-01-01  Albany
# 3     5811.16     5677.40      133.76          0.0     0 2015-01-01  Albany
# 4     6183.95     5986.26      197.69          0.0     0 2015-01-01  Albany

# %%
color2 = ['#DF3C22','#203EB9', '#F5EE04','#50CD27']

sns.catplot(x='Total Volume',y='region', data = df, hue = 'year',height = 8,palette = color2,kind = 'point')
plt.title('Total de Volumen by region',fontsize=10,weight='bold')
plt.show()

# %%
color1 = ['#296C92','#3EB489']
sns.catplot(x='Total Volume',y='region',data = df,hue = 'type',height = 8,palette = color1 ,kind = 'point')
plt.title('Total de volumen by region',fontsize=10,weight='bold')
plt.show()

# %%
df.shape
# Out:
# (18249, 13)

# %%
df1=df.copy(deep=True)
df1.set_index('Date',inplace=True)
df1=df1.resample('W').sum()
df1=df1[['AveragePrice']]
df1.head()
# Out:
#             AveragePrice
# Date
# 2015-01-04        140.54
# 2015-01-11        148.03
# 2015-01-18        150.24
# 2015-01-25        150.89
# 2015-02-01        134.68

# %% [markdown]
# ## **Time Series**

# %%
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf,pacf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.arima.model import ARIMA

# %%
decompose_data=seasonal_decompose(df1['AveragePrice'],model='aditive',period = 52)
decompose_data.plot()
plt.xticks(rotation='vertical')
plt.show()

# %%
decompose_data=seasonal_decompose(df1['AveragePrice'],model='multiplicative',period = 52)
decompose_data.plot()
plt.xticks(rotation='vertical')
plt.show()

# %%
def test_stationarity(timeseries):
  timeseries.dropna(inplace=True)
  rolmean=timeseries.rolling(window=12).mean() #promedio
  rolstd=timeseries.rolling(window=12).std() #STD

  orig=plt.plot(timeseries,label='Original')
  mean=plt.plot(rolmean,label='Rolling mean')
  std=plt.plot(rolstd,label='Rolling std')


  plt.legend(loc='best')
  plt.title('TimeSeries data with rolling mean and std',fontsize=10,weight='bold')
  plt.xticks(rotation='vertical',weight='bold')
  plt.xlabel('Fecha',weight='bold')
  plt.ylabel('Average',weight='bold')
  plt.tight_layout()
  plt.show()

  from statsmodels.tsa.stattools import adfuller

  df_test=adfuller(timeseries)
  df_output=pd.Series(df_test[0:4],index=['The Test statistic','Mackinnons aproximate p-value','usedLags','NOBS'])
  print('')
  print(df_output)

# %%
def Prueba_Dickey_Fuller(series , column_name):
    print (f'Resultados de la prueba de Dickey-Fuller para columna: {column_name}')
    dftest = adfuller(series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','No Lags Used','Número de observaciones utilizadas'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    if dftest[1] <= 0.05:
        print("Conclusion:====>")
        print("Rechazar la hipótesis nula")
        print("Los datos son estacionarios")
    else:
        print("Conclusion:====>")
        print("No se puede rechazar la hipótesis nula")
        print("Los datos no son estacionarios")

# %%
Prueba_Dickey_Fuller(df1['AveragePrice'],'AveragePrice')
# Out:
# Resultados de la prueba de Dickey-Fuller para columna: AveragePrice
# Test Statistic                         -2.363645
# p-value                                 0.152261
# No Lags Used                            0.000000
# Número de observaciones utilizadas    168.000000
# Critical Value (1%)                    -3.469886
# Critical Value (5%)                    -2.878903
# Critical Value (10%)                   -2.576027
# dtype: float64
# Conclusion:====>
# No se puede rechazar la hipótesis nula
# Los datos no son estacionarios

# %%
test_stationarity(df1)
# Out:
# The Test statistic                -2.363645
# Mackinnons aproximate p-value      0.152261
# usedLags                           0.000000
# NOBS                             168.000000
# dtype: float64

# %%
df_log=np.log(df1)
test_stationarity(df_log)
# Out:
# The Test statistic                -2.495713
# Mackinnons aproximate p-value      0.116521
# usedLags                           0.000000
# NOBS                             168.000000
# dtype: float64

# %%
Prueba_Dickey_Fuller(df_log['AveragePrice'],'AveragePrice')
# Out:
# Resultados de la prueba de Dickey-Fuller para columna: AveragePrice
# Test Statistic                         -2.495713
# p-value                                 0.116521
# No Lags Used                            0.000000
# Número de observaciones utilizadas    168.000000
# Critical Value (1%)                    -3.469886
# Critical Value (5%)                    -2.878903
# Critical Value (10%)                   -2.576027
# dtype: float64
# Conclusion:====>
# No se puede rechazar la hipótesis nula
# Los datos no son estacionarios

# %%
ma=df_log.rolling(window=12).mean()
df_log_ma=df_log-ma
test_stationarity(df_log_ma)
# Out:
# The Test statistic                -4.341349
# Mackinnons aproximate p-value      0.000376
# usedLags                           6.000000
# NOBS                             151.000000
# dtype: float64

# %%
Prueba_Dickey_Fuller(df_log_ma['AveragePrice'],'AveragePrice')
# Out:
# Resultados de la prueba de Dickey-Fuller para columna: AveragePrice
# Test Statistic                         -4.341349
# p-value                                 0.000376
# No Lags Used                            6.000000
# Número de observaciones utilizadas    151.000000
# Critical Value (1%)                    -3.474416
# Critical Value (5%)                    -2.880878
# Critical Value (10%)                   -2.577081
# dtype: float64
# Conclusion:====>
# Rechazar la hipótesis nula
# Los datos son estacionarios

# %%
df_log_ma.shape
# Out:
# (158, 1)

# %%
a=158*0.50
a
# Out:
# 79.0

# %%
lag_acf=acf(df_log_ma,nlags=10)
lag_pacf=acf(df_log_ma,nlags=34)

fig,ax=plt.subplots(1,2,figsize=(20,5))
plot_acf(lag_acf,ax=ax[0]) #columna 0
plot_pacf(lag_pacf,ax=ax[1]) #columna 1
plt.tight_layout()
plt.show()

# %%
model = ARIMA(df_log_ma['AveragePrice'],order = (1,1,2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:           AveragePrice   No. Observations:                  158
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                 297.617
# Date:                Wed, 20 Sep 2023   AIC                           -587.234
# Time:                        01:40:50   BIC                           -575.009
# Sample:                    03-22-2015   HQIC                          -582.269
#                          - 03-25-2018
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1448      0.863     -0.168      0.867      -1.837       1.547
# ma.L1          0.0901      0.849      0.106      0.915      -1.574       1.754
# ma.L2         -0.1030      0.090     -1.148      0.251      -0.279       0.073
# ...
